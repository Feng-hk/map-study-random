# %%
"""
The purposes of this code;
1. when and where will she be able to see an eclipse?
2. which upcoming eclipse will pass over the most people?
3. what are the largest cities in that eclipse?
"""
# Out:
# '\nThe purposes of this code;\n1. when and where will she be able to see an eclipse?\n2. which upcoming eclipse will pass over the most people?\n3. what are the largest cities in that eclipse?\n'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import descartes

# %%
import pandas as pd
import geopandas as gpd

# %%
# GeoPandas comes with some data that we can quickly load in
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# Adn check out the top few rows... it comes with attributes like population and gdp,
# as well as geometry
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# use the pliot method to view the spatial component
world.plot()

# %%
# you'll usually want to customize how your map looks
world.plot(color='grey', linewidth=0.5, edgecolor='white', figsize=(15,10))

# %%
# we'll need to load in some local data
import os
data_path = "../Data/ne_10m_populated_places_simple"
# Geopandas comes with city data, but its just the capital cities. so additional load in my own.
cities = gpd.read_file(os.path.join(data_path, "ne_10m_populated_places.shp"))
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../Data/ne_10m_populated_places_simple\ne_10m_populated_places.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-19-59dad947b17a> in <module>
#       3 data_path = "../Data/ne_10m_populated_places_simple"
#       4 # Geopandas comes with city data, but its just the capital cities. so additional load in my own.
# ----> 5 cities = gpd.read_file(os.path.join(data_path, "ne_10m_populated_places.shp"))
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ...
